# %%
import torch

# %%
print(torch.version.cuda)
# Out:
# 12.4

# %%
# !nvidia-smi --query-gpu=name --format=csv,noheader
# Out:
# Quadro RTX 6000
# Quadro RTX 6000
# Quadro RTX 6000
# Quadro RTX 6000
# Quadro RTX 6000
# Quadro RTX 6000
# Quadro RTX 6000
# Quadro RTX 6000
